# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/avocado.csv',index_col=0)

# %% [markdown]
# In this data 4046,4225,4770 are price look up code for different range of avacado ,There column stores the quantity sold

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume  ...          type  year  region
# 0  2015-12-27          1.33      64236.62  ...  conventional  2015  Albany
# 1  2015-12-20          1.35      54876.98  ...  conventional  2015  Albany
# 2  2015-12-13          0.93     118220.22  ...  conventional  2015  Albany
# 3  2015-12-06          1.08      78992.15  ...  conventional  2015  Albany
# 4  2015-11-29          1.28      51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume  ...    XLarge Bags          year
# count  18249.000000  1.824900e+04  ...   18249.000000  18249.000000
# mean       1.405978  8.506440e+05  ...    3106.426507   2016.147899
# std        0.402677  3.453545e+06  ...   17692.894652      0.939938
# min        0.440000  8.456000e+01  ...       0.000000   2015.000000
# 25%        1.100000  1.083858e+04  ...       0.000000   2015.000000
# 50%        1.370000  1.073768e+05  ...       0.000000   2016.000000
# 75%        1.660000  4.329623e+05  ...     132.500000   2017.000000
# max        3.250000  6.250565e+07  ...  551693.650000   2018.000000
#
# [8 rows x 10 columns]

# %%
df.nunique()
# Out:
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# NO NULL VALUES--## df.dropna(,inplace=True)

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume  ...    XLarge Bags          year
# count  18249.000000  1.824900e+04  ...   18249.000000  18249.000000
# mean       1.405978  8.506440e+05  ...    3106.426507   2016.147899
# std        0.402677  3.453545e+06  ...   17692.894652      0.939938
# min        0.440000  8.456000e+01  ...       0.000000   2015.000000
# 25%        1.100000  1.083858e+04  ...       0.000000   2015.000000
# 50%        1.370000  1.073768e+05  ...       0.000000   2016.000000
# 75%        1.660000  4.329623e+05  ...     132.500000   2017.000000
# max        3.250000  6.250565e+07  ...  551693.650000   2018.000000
#
# [8 rows x 10 columns]

# %% [markdown]
# dropping the rows having 0 quantity sold of any 1 variety

# %%
df=df[(df['4046']!=0)&(df['4225']!=0)&(df['4770']!=0)]

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume  ...    XLarge Bags          year
# count  12752.000000  1.275200e+04  ...   12752.000000  12752.000000
# mean       1.313799  1.209547e+06  ...    4445.460165   2016.147193
# std        0.383814  4.079292e+06  ...   21024.689703      0.931196
# min        0.460000  8.671800e+02  ...       0.000000   2015.000000
# 25%        1.030000  7.919830e+04  ...       0.000000   2015.000000
# 50%        1.240000  2.503304e+05  ...       0.000000   2016.000000
# 75%        1.550000  7.166504e+05  ...    1039.165000   2017.000000
# max        3.040000  6.250565e+07  ...  551693.650000   2018.000000
#
# [8 rows x 10 columns]

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume  ...          type  year  region
# 0  2015-12-27          1.33      64236.62  ...  conventional  2015  Albany
# 1  2015-12-20          1.35      54876.98  ...  conventional  2015  Albany
# 2  2015-12-13          0.93     118220.22  ...  conventional  2015  Albany
# 3  2015-12-06          1.08      78992.15  ...  conventional  2015  Albany
# 4  2015-11-29          1.28      51039.60  ...  conventional  2015  Albany
#
# [5 rows x 13 columns]

# %%
df['region'].value_counts()
# Out:
# BaltimoreWashington    338
# Denver                 338
# Midsouth               338
# SouthCarolina          338
# Northeast              338
# West                   338
# RaleighGreensboro      338
# Southeast              338
# TotalUS                338
# RichmondNorfolk        338
# Charlotte              338
# NewYork                337
# Seattle                334
# Plains                 333
# HarrisburgScranton     322
# Jacksonville           320
# Philadelphia           319
# Portland               288
# HartfordSpringfield    287
# WestTexNewMexico       258
# California             254
# GreatLakes             233
# LosAngeles             225
# StLouis                214
# Spokane                210
# SouthCentral           205
# SanDiego               202
# Columbus               195
# Sacramento             188
# Nashville              188
# SanFrancisco           188
# Pittsburgh             186
# Boston                 179
# Indianapolis           174
# ...

# %%
albany_df = df[df['region']=='Albany']
albany_df = albany_df.set_index('Date') #albany_df.set_index('Data,inplace=True)

# %%
albany_df.head(2)
# Out:
#             AveragePrice  Total Volume     4046  ...          type  year  region
# Date                                             ...
# 2015-12-27          1.33      64236.62  1036.74  ...  conventional  2015  Albany
# 2015-12-20          1.35      54876.98   674.28  ...  conventional  2015  Albany
#
# [2 rows x 12 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
albany_df=df[df['region']=='Albany']
albany_df.set_index('Date',inplace = True)
albany_df['AveragePrice'].plot()

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
#albany_df.index
albany_df.sort_index(inplace=True)
albany_df['AveragePrice'].rolling(25).mean().plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
albany_df['Price25ma']=albany_df['AveragePrice'].rolling(25).mean()
albany_df.dropna().head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             Unnamed: 0  AveragePrice  Total Volume  ...  year  region  Price25ma
# Date                                                ...
# 2015-03-29          39          1.93       1082.44  ...  2015  Albany     1.4660
# 2015-03-29          39          1.02      67799.08  ...  2015  Albany     1.4580
# 2015-04-05          38          1.16      47362.13  ...  2015  Albany     1.4328
# 2015-04-05          38          1.93       1526.10  ...  2015  Albany     1.4604
# 2015-04-12          37          1.76       1634.59  ...  2015  Albany     1.4600
#
# [5 rows x 14 columns]

# %%
albany_df =df.copy()[df['region']=='Albany']
albany_df.set_index('Date',inplace= True)
albany_df.sort_index(inplace=True)
albany_df['Price25ma']=albany_df['AveragePrice'].rolling(25).mean()
list(set(df['region'].tolist()))
# Out:
# ['Boise',
#  'Syracuse',
#  'HarrisburgScranton',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Spokane',
#  'GrandRapids',
#  'Louisville',
#  'NewOrleansMobile',
#  'Pittsburgh',
#  'TotalUS',
#  'Jacksonville',
#  'Detroit',
#  'Denver',
#  'Tampa',
#  'NorthernNewEngland',
#  'SouthCentral',
#  'GreatLakes',
#  'PhoenixTucson',
#  'SanFrancisco',
#  'Seattle',
#  'California',
#  'Albany',
#  'Atlanta',
#  'DallasFtWorth',
#  'LasVegas',
#  'West',
#  'Houston',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Indianapolis',
#  'Southeast',
#  'Orlando',
#  'WestTexNewMexico',
#  'Charlotte',
#  'NewYork',
#  'Philadelphia',
#  'SanDiego',
#  'BaltimoreWashington',
#  'SouthCarolina',
#  'LosAngeles',
#  'Sacramento',
#  'Boston',
#  'HartfordSpringfield',
#  'Northeast',
#  'StLouis',
#  'BuffaloRochester',
#  'CincinnatiDayton',
#  'Columbus',
#  'Roanoke',
#  'Nashville',
#  'Chicago']

# %%
df['region'].nunique()
# Out:
# 54

# %%
graph_df =pd.DataFrame()
for region in df['region'].unique()[:16]:
    print(region)
    region_df =df.copy()[df['region']==region]
    region_df.set_index('Date',inplace= True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma']=region_df['AveragePrice'].rolling(25).mean()                   
    
    if graph_df.empty:
        graph_df=region_df[[f'{region}_price25ma']]
    else :
        graph_df=graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
graph_df.tail()
# Out:
#             Albany_price25ma  ...  GreatLakes_price25ma
# Date                          ...
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
#
# [5 rows x 16 columns]

# %%
df=df.copy()[df['type']=='organic']
df['Date'] = pd.to_datetime(df['Date'])

df.sort_values(by='Date',ascending=True,inplace=True)
graph_df =pd.DataFrame()
for region in df['region'].unique()[:16]:
    print(region)
    region_df =df.copy()[df['region']==region]
    region_df.set_index('Date',inplace= True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma']=region_df['AveragePrice'].rolling(25).mean()                   
    
    if graph_df.empty:
        graph_df=region_df[[f'{region}_price25ma']]
    else :
        graph_df=graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington

# %%
graph_df.tail()
# Out:
#             California_price25ma  ...  BaltimoreWashington_price25ma
# Date                              ...
# 2018-02-25                1.9128  ...                         1.5836
# 2018-03-04                1.8876  ...                         1.5772
# 2018-03-11                1.8636  ...                         1.5732
# 2018-03-18                1.8516  ...                         1.5684
# 2018-03-25                1.8364  ...                         1.5568
#
# [5 rows x 16 columns]

# %%
graph_df.dropna().plot(figsize=(15,8),legend=False)

# %%
df['region']
# Out:
# 9489              California
# 10269               LasVegas
# 10893          PhoenixTucson
# 9437        BuffaloRochester
# 11621                Spokane
#                 ...
# 17913              Nashville
# 17925       NewOrleansMobile
# 17625    BaltimoreWashington
# 17865             LosAngeles
# 17949              Northeast
# Name: region, Length: 9123, dtype: object

# %%
list(df['region'].unique())
# Out:
# ['California',
#  'LasVegas',
#  'PhoenixTucson',
#  'BuffaloRochester',
#  'Spokane',
#  'LosAngeles',
#  'Philadelphia',
#  'Boston',
#  'StLouis',
#  'Louisville',
#  'Orlando',
#  'Southeast',
#  'Boise',
#  'MiamiFtLauderdale',
#  'NorthernNewEngland',
#  'BaltimoreWashington',
#  'Midsouth',
#  'Tampa',
#  'West',
#  'Northeast',
#  'Atlanta',
#  'Nashville',
#  'TotalUS',
#  'Syracuse',
#  'WestTexNewMexico',
#  'Jacksonville',
#  'Charlotte',
#  'Sacramento',
#  'GrandRapids',
#  'Roanoke',
#  'Denver',
#  'SanDiego',
#  'GreatLakes',
#  'RichmondNorfolk',
#  'DallasFtWorth',
#  'SanFrancisco',
#  'HarrisburgScranton',
#  'Pittsburgh',
#  'RaleighGreensboro',
#  'Seattle',
#  'HartfordSpringfield',
#  'Portland',
#  'CincinnatiDayton',
#  'SouthCarolina',
#  'Houston',
#  'Chicago',
#  'Plains',
#  'Indianapolis',
#  'SouthCentral',
#  'Columbus',
#  'Albany',
#  'Detroit',
#  'NewOrleansMobile',
#  'NewYork']

# %%
df['Date']=pd.to_datetime(df['Date'])
Boston_df=df[df['region']=='Boston']
Boston_df.set_index('Date',inplace=True)
Boston_df.sort_index9inplace=True
Boston_df['AveragePrice'].plot()

# %%
Boston_df['AveragePrice'].dropna().rolling(2).mean().plot()

# %%
Boston_df['Price25ma']=Boston_df['AveragePrice'].rolling(25).mean()
Boston_df.dropna().plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
