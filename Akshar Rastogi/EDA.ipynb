# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('/content/drive/MyDrive/python/water_potability.csv')

# %%
df
# Out:
#             ph    Hardness  ...  Turbidity  Potability
# 0          NaN  204.890455  ...   2.963135           0
# 1     3.716080  129.422921  ...   4.500656           0
# 2     8.099124  224.236259  ...   3.055934           0
# 3     8.316766  214.373394  ...   4.628771           0
# 4     9.092223  181.101509  ...   4.075075           0
# ...        ...         ...  ...        ...         ...
# 3271  4.668102  193.681735  ...   4.435821           1
# 3272  7.808856  193.553212  ...   2.798243           1
# 3273  9.419510  175.762646  ...   3.298875           1
# 3274  5.126763  230.603758  ...   4.708658           1
# 3275  7.874671  195.102299  ...   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
#there are no null values in our data
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 ph     Hardness  ...    Turbidity   Potability
# count  2785.000000  3276.000000  ...  3276.000000  3276.000000
# mean      7.080795   196.369496  ...     3.966786     0.390110
# std       1.594320    32.879761  ...     0.780382     0.487849
# min       0.000000    47.432000  ...     1.450000     0.000000
# 25%       6.093092   176.850538  ...     3.439711     0.000000
# 50%       7.036752   196.967627  ...     3.955028     0.000000
# 75%       8.062066   216.667456  ...     4.500320     1.000000
# max      14.000000   323.124000  ...     6.739000     1.000000
#
# [8 rows x 10 columns]

# %%
df['ph'] = df['ph'].fillna(0)

# %%
df = df.fillna(df.mean)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               3276 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          3276 non-null   object
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3276 non-null   object
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 256.1+ KB

# %%
df.describe()
# Out:
#                 ph     Hardness  ...    Turbidity   Potability
# count  3276.000000  3276.000000  ...  3276.000000  3276.000000
# mean      6.019540   196.369496  ...     3.966786     0.390110
# std       2.924207    32.879761  ...     0.780382     0.487849
# min       0.000000    47.432000  ...     1.450000     0.000000
# 25%       5.283146   176.850538  ...     3.439711     0.000000
# 50%       6.735249   196.967627  ...     3.955028     0.000000
# 75%       7.870050   216.667456  ...     4.500320     1.000000
# max      14.000000   323.124000  ...     6.739000     1.000000
#
# [8 rows x 8 columns]

# %%
df['Sulfate'] == float()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3271    False
# 3272    False
# 3273    False
# 3274    False
# 3275    False
# Name: Sulfate, Length: 3276, dtype: bool

# %%
df_a = df.drop(columns='Sulfate')

# %%
cols = [df.columns]
df[cols] = df[cols].applymap(np.int64)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-125-1c88afdfe434> in <module>()
#       1 cols = [df.columns]
# ----> 2 df[cols] = df[cols].applymap(np.int64)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
dfa = df_a
df_a.info()

# %%
a = df_a['Trihalomethanes'] == float()

# %%
a.unique()
# Out:
# array([False])

# %%
ac = []
for i in  range(len(a)):
  if a[i]  ==
# Out:
#   File "<ipython-input-128-03660c9f8367>", line 3
#     if a[i]  ==
#                 ^
# SyntaxError: invalid syntax

# %%
dfa['Trihalomethanes'] = dfa.Trihalomethanes.astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-b65ecda5a0f6> in <module>()
# ----> 1 dfa['Trihalomethanes'] = dfa.Trihalomethanes.astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5546         else:
#    5547             # else, only a single dtype is given
# -> 5548             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5549             return self._constructor(new_data).__finalize__(self, method="astype")
#    5550
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     602         self, dtype, copy: bool = False, errors: str = "raise"
#     603     ) -> "BlockManager":
# --> 604         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     605
#     606     def convert(
#
# ...

# %%
pd.to_numeric(a, errors='ignore')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3271    False
# 3272    False
# 3273    False
# 3274    False
# 3275    False
# Name: Trihalomethanes, Length: 3276, dtype: bool

# %%
pd.to_numeric(a, errors='coerce')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3271    False
# 3272    False
# 3273    False
# 3274    False
# 3275    False
# Name: Trihalomethanes, Length: 3276, dtype: bool

# %%
b = dfa['Trihalomethanes']

# %%
dfb = dfa.drop(columns='Trihalomethanes')

# %%
dfb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ph              3276 non-null   float64
#  1   Hardness        3276 non-null   float64
#  2   Solids          3276 non-null   float64
#  3   Chloramines     3276 non-null   float64
#  4   Conductivity    3276 non-null   float64
#  5   Organic_carbon  3276 non-null   float64
#  6   Turbidity       3276 non-null   float64
#  7   Potability      3276 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 204.9 KB

# %%
sns.heatmap(dfb)

# %%
dfb.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Conductivity',
#        'Organic_carbon', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
dfb = dfb.round(1)

# %%
chloro = dfb['Chloramines']
hard = dfb['Hardness']
solid = dfb['Solids']
ph = dfb['ph']
conduct = dfb['Conductivity']
carbon = dfb['Organic_carbon']
turb = dfb['Turbidity']
pota = dfb['Potability']

# %%
sns.scatterplot(x=ph, y=turb, hue=pota)

# %%
sns.scatterplot(x=solid, y=chloro, hue=pota)

# %%
sns.scatterplot(x=solid, y=hard, hue=pota)

# %%
ax = plt.axes(projection='3d')
ax.plot_trisurf(ph, solid, chloro, color='green')

# %%
sns.barplot(x=ph, y=chloro, hue=pota)

# %%
dfc = dfb
dfc
# Out:
#        ph  Hardness   Solids  ...  Organic_carbon  Turbidity  Potability
# 0     0.0     204.9  20791.3  ...            10.4        3.0           0
# 1     3.7     129.4  18630.1  ...            15.2        4.5           0
# 2     8.1     224.2  19909.5  ...            16.9        3.1           0
# 3     8.3     214.4  22018.4  ...            18.4        4.6           0
# 4     9.1     181.1  17979.0  ...            11.6        4.1           0
# ...   ...       ...      ...  ...             ...        ...         ...
# 3271  4.7     193.7  47581.0  ...            13.9        4.4           1
# 3272  7.8     193.6  17329.8  ...            19.9        2.8           1
# 3273  9.4     175.8  33155.6  ...            11.0        3.3           1
# 3274  5.1     230.6  11983.9  ...            11.2        4.7           1
# 3275  7.9     195.1  17404.2  ...            16.1        2.3           1
#
# [3276 rows x 8 columns]

# %%
def range_def(df ,column):
  rangereturn = []
  if (df [column]> 0) & (df [column] < 3).any():
    mark ='0-3'
    rangereturn.append(mark)
  elif (df [column] > 3) & (df [column] <5).any():
    mark ='3-5'
    rangereturn.append(mark)   
  elif (df [column] > 5) & (df [column] <7).any():
    mark ='5-7'
    rangereturn.append(mark)
  elif (df [column] > 7) &  (df [column] < 9).any():
    mark ='7-9'
    rangereturn.append(mark)          
  elif (df [column] > 9) & (df [column] <11).any():
    mark ='9-11'
    rangereturn.append(mark)     
  elif (df [column] > 11) & (df [column] < 14).any():
    mark ='11-14'
    rangereturn.append(mark)

# %%
range_def(dfc, ph)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-be63a427ed21> in <module>()
# ----> 1 range_def(dfc, ph)
#
# <ipython-input-159-31bd81668c94> in range_def(df, column)
#       1 def range_def(df ,column):
#       2   rangereturn = []
# ----> 3   if (df [column]> 0) & (df [column] < 3).any():
#       4     mark ='0-3'
#       5     rangereturn.append(mark)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2910             if is_iterator(key):
#    2911                 key = list(key)
# -> 2912             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2913
#    2914         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
# ...
