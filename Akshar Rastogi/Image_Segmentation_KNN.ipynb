# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
import cv2

# %%
image = cv2.imread('/content/drive/MyDrive/python/img.jpg')

# %%
image
# Out:
# array([[[248, 208,  60],
#         [248, 208,  60],
#         [249, 209,  61],
#         ...,
#         [248, 227,  15],
#         [242, 228,  16],
#         [240, 230,  12]],
#
#        [[249, 206,  59],
#         [248, 208,  60],
#         [251, 208,  61],
#         ...,
#         [251, 226,  16],
#         [248, 228,  13],
#         [246, 229,  12]],
#
#        [[249, 204,  59],
#         [248, 204,  59],
#         [250, 205,  60],
#         ...,
#         [255, 223,  15],
#         [255, 226,   9],
#         [254, 227,   9]],
#
#        ...,
#
#        [[246, 220,  19],
#         [250, 223,  18],
#         [255, 229,  19],
#         ...,
#         [250, 171,  14],
#         [233, 142,   9],
#         [216, 120,   3]],
#
#        [[248, 213,  15],
#         [248, 214,  14],
#         [250, 216,   9],
#         ...,
#         [248, 177,  13],
#         [239, 157,   8],
#         [230, 142,   6]],
#
#        [[252, 212,  16],
#         [252, 213,  14],
#         [252, 215,  11],
#         ...,
#         [246, 179,  10],
#         [237, 160,   3],
#         [231, 145,   1]]], dtype=uint8)

# %%
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
vectorized = image.reshape((-1, 3))

# %%
'''
lets convert our image to a vectorizes array
'''
vectorized = np.float32(vectorized)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
#

# %%
K = 4
attempts = 10
ret, label, center = cv2.kmeans(vectorized, K, None, criteria, attempts, cv2.KMEANS_PP_CENTERS)

# %%
#to convert it into uint8
center = np.uint8(center)

# %%
res = center[label.flatten()]
result_image = res.reshape((img.shape))

# %%
figure_size = 15
plt.figure(figsize=(figure_size, figure_size))
plt.subplot(1,2,1)
plt.imshow(img)
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.subplot(1,2,2)
plt.imshow(result_image)
plt.title('Segmented Image when K = %i' %K)
plt.xticks([])
plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show>
