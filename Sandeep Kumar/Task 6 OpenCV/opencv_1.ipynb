# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('img1.png')

# %%
plt.imshow(img) # By default it is read as BGR so the B channel is on up

# %%
newimg=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(newimg)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        ...,
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239],
# ...
